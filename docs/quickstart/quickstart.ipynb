# %% [markdown]
# # Quelques exemples pour démarrer

# %%
# Import le client pour interagir avec l'API
from apifoncier import ApiFoncierClient

import plotly.io as pio

pio.renderers.default = "notebook"

# %% [markdown]
# ## Utilisation du client

# %%
# On instancie le client
client = ApiFoncierClient()

# Exemples sur Cartofriches (commune de Lille)
friches = client.cartofriches.friches(code_insee="59350")

# Affichage des 5 premières friches du dataframe
friches.head()
# Out:
# /cartofriches/friches: 100%|██████████| 138/138 [00:00<00:00, 69054.40enreg./s]
#        site_id                            site_nom site_type site_adresse  \
# 0  59350_10190                         Teinturerie   inconnu         None
# 1  59350_10192                      WILVIA MEUBLEX   inconnu         None
# 2  59350_10209                Atelier de mécanique   inconnu         None
# 3  59350_10210                Station Service Esso   inconnu         None
# 4  59350_10211  Assitance et Inspection Techniques   inconnu         None
#
#           site_statut comm_nom comm_insee dep proprio_personne  \
# 0  friche potentielle    LILLE      59350  59  personne morale
# 1  friche potentielle    LILLE      59350  59  personne morale
# 2  friche potentielle    LILLE      59350  59  personne morale
# 3  friche potentielle    LILLE      59350  59  personne morale
# 4  friche potentielle    LILLE      59350  59  personne morale
#
#    unite_fonciere_surface unite_fonciere_refcad  \
# 0              234.171185    ['59350000IK0025']
# 1              234.171185    ['59350000IK0025']
# 2              234.171185    ['59350000IK0025']
# 3              234.171185    ['59350000IK0025']
# 4              234.171185    ['59350000IK0025']
#
#                                        source_nom           nature  \
# 0  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 1  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 2  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 3  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 4  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
#
#   urba_zone_type
# 0              U
# 1              U
# 2              U
# 3              U
# 4              U

# %%
# Equivalent avec un context-manager
with ApiFoncierClient() as client:
    friches = client.cartofriches.friches(code_insee="59350")

friches.head()
# Out:
# /cartofriches/friches: 100%|██████████| 138/138 [00:00<00:00, 135047.59enreg./s]
#        site_id                            site_nom site_type site_adresse  \
# 0  59350_10190                         Teinturerie   inconnu         None
# 1  59350_10192                      WILVIA MEUBLEX   inconnu         None
# 2  59350_10209                Atelier de mécanique   inconnu         None
# 3  59350_10210                Station Service Esso   inconnu         None
# 4  59350_10211  Assitance et Inspection Techniques   inconnu         None
#
#           site_statut comm_nom comm_insee dep proprio_personne  \
# 0  friche potentielle    LILLE      59350  59  personne morale
# 1  friche potentielle    LILLE      59350  59  personne morale
# 2  friche potentielle    LILLE      59350  59  personne morale
# 3  friche potentielle    LILLE      59350  59  personne morale
# 4  friche potentielle    LILLE      59350  59  personne morale
#
#    unite_fonciere_surface unite_fonciere_refcad  \
# 0              234.171185    ['59350000IK0025']
# 1              234.171185    ['59350000IK0025']
# 2              234.171185    ['59350000IK0025']
# 3              234.171185    ['59350000IK0025']
# 4              234.171185    ['59350000IK0025']
#
#                                        source_nom           nature  \
# 0  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 1  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 2  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 3  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
# 4  Site Basias ou Basol non vérifié par le Cerema  MTE non vérifié
#
#   urba_zone_type
# 0              U
# 1              U
# 2              U
# 3              U
# 4              U

# %% [markdown]
# ## Configuration du client

# %%
# Jeton API pour authentification sur les endpoints restreints de l'API
token = "votre_jeton_api_ici"

# Dictionnaire pour la configuration du client
config = {
    "api_key": token,
    "progress_bar": False,  # Désactive la barre de progression
    "timeout": 10,  # Délai d'attente pour les requêtes en secondes
    "max_retries": 3,  # Nombre maximum de tentatives en cas d'échec
    "base_url": "https://apidf.k8-dev.cerema.fr",
}

# Instanciation du client avec la configuration
client = ApiFoncierClient(config)

# ou
with ApiFoncierClient(config) as client:
    pass

# %% [markdown]
# ## Exemples d'utilisation

# %%
# Récupération des transactions pour une commune spécifique (ici, Rouen) issues de DVF+ open-data
mutations = client.dvf_opendata.mutations(
    code_insee="76540", anneemut_min=2020, anneemut_max=2024
)

# Répartition des mutations selon le type de bien
print("Nombre de mutations sur la période 2020-2024: ", mutations.shape[0])
mutations.value_counts("libtypbien")
# Out:
# Nombre de mutations sur la période 2020-2024:  16885
# libtypbien
# UN APPARTEMENT                               10347
# UNE MAISON                                    1909
# BATI - INDETERMINE : Vefa sans descriptif     1182
# ACTIVITE                                      1003
# UNE DEPENDANCE                                 791
# APPARTEMENT INDETERMINE                        400
# BATI MIXTE - LOGEMENT/ACTIVITE                 349
# DEUX APPARTEMENTS                              333
# DES DEPENDANCES                                182
# TERRAIN ARTIFICIALISE MIXTE                    134
# BATI - INDETERMINE : Vente avec volume(s)      126
# DES MAISONS                                     49
# TERRAIN DE TYPE TAB                             36
# BATI MIXTE - LOGEMENTS                          27
# TERRAIN DE TYPE RESEAU                           4
# TERRAIN D'AGREMENT                               4
# TERRAIN NON BATIS INDETERMINE                    4
# TERRAIN FORESTIER                                2
# TERRAIN VERGER                                   2
# TERRAIN LANDES ET EAUX                           1
# Name: count, dtype: int64

# %%
# Récupération des indicateurs de prix pour des communes en 2024
prix = client.indicateurs.prix(
    codes=[
        "75056",  # Paris
        "13055",  # Marseille
        "69123",  # Lyon
        "31555",  # Toulouse
        "06088",  # Nice
        "44109",  # Nantes
        "34172",  # Montpellier
        "67482",  # Strasbourg
        "33063",  # Bordeaux
        "59350",  # Lille
    ],
    echelle="communes",
    annee="2024",
    type_prix="annuel",
)

# Affichage des prix médians au m² des appartements anciens pour les principales villes françaises
prix[["libelle", "annee", "pxm2_median_cod1213"]].sort_values(
    "pxm2_median_cod1213", ascending=False
).rename(
    columns={
        "libelle": "Commune",
        "annee": "Année",
        "pxm2_median_cod1213": "Prix médian (€/m2)",
    }
)
# Out:
#        Commune Année  Prix médian (€/m2)
# 8        Paris  2024            9835.290
# 0         Nice  2024            4893.620
# 7         Lyon  2024            4555.560
# 3     Bordeaux  2024            4346.940
# 2     Toulouse  2024            3685.710
# 6        Lille  2024            3621.670
# 4  Montpellier  2024            3541.840
# 5       Nantes  2024            3482.425
# 1    Marseille  2024            3305.115

# %%
# Récupération des indicateurs de consommation d'espace pour la commune d'Arras (code INSEE 62041)
conso_espace = client.indicateurs.conso(
    code="62041",
    annee_min=2010,
    echelle="communes",
)

# Affichage des surfaces artificialisées pour la commune d'Arras
conso_espace[["annee", "idcomtxt", "naf_arti"]].rename(
    columns={
        "idcomtxt": "Nom de la commune",
        "naf_arti": "Surface artificialisée (m2)",
        "annee": "Année",
    }
)
# Out:
#     Année Nom de la commune  Surface artificialisée (m2)
# 0    2010             Arras                         6782
# 1    2011             Arras                         6820
# 2    2012             Arras                        37627
# 3    2013             Arras                       260499
# 4    2014             Arras                        15198
# 5    2015             Arras                        15888
# 6    2016             Arras                        20942
# 7    2017             Arras                        19079
# 8    2018             Arras                        44201
# 9    2019             Arras                        53291
# 10   2020             Arras                         4665
# 11   2021             Arras                            0
# 12   2022             Arras                         2974
# 13   2023             Arras                         1710

# %%
# Récupération des friches au format geojson pour la Moselle
geofriches = client.cartofriches.geofriches(coddep="57", format_output="dict")

# Affichage de la carte avec les friches
# (nécessite la bibliothèque folium)
import folium

m = folium.Map(location=[49.1193, 6.1752], zoom_start=11)
folium.GeoJson(
    data=geofriches,  # Dictionnaire GeoJSON
    name="Friches",
    style_function=lambda x: {
        "color": "darkred",
        "weight": 1,
        "fillOpacity": 0.5,
    },
    tooltip=folium.features.GeoJsonTooltip(
        fields=["site_nom"],
        aliases=["Nom:"],
    ),
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd9dca2821521928c6aa4149b329d7d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd9dca2821521928c6aa4149b329d7d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd9dca2821521928c6aa4149b329d7d1 = L.map(
#                 &quot;map_cd9dca2821521928c6aa4149b329d7d1&quot;,
#                 {
#                     center: [49.1193, 6.1752],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df194cc1f09e67f37680522370c4380d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df194cc1f09e67f37680522370c4380d.addTo(map_cd9dca2821521928c6aa4149b329d7d1);
#
#
#         function geo_json_67e73b1bd0c005c1df88bd7ba17c34db_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_67e73b1bd0c005c1df88bd7ba17c34db_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_67e73b1bd0c005c1df88bd7ba17c34db = L.geoJson(null, {
#                 onEachFeature: geo_json_67e73b1bd0c005c1df88bd7ba17c34db_onEachFeature,
#
#                 style: geo_json_67e73b1bd0c005c1df88bd7ba17c34db_styler,
#             ...{
# }
#         });
#
#         function geo_json_67e73b1bd0c005c1df88bd7ba17c34db_add (data) {
#             geo_json_67e73b1bd0c005c1df88bd7ba17c34db
#                 .addData(data);
#         }
#             geo_json_67e73b1bd0c005c1df88bd7ba17c34db_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[7.085063, 48.639218], [7.085505, 48.639396], [7.089551, 48.638612], [7.089189, 48.638212], [7.089457, 48.638151], [7.091171, 48.637421], [7.090946, 48.637274], [7.090056, 48.636595], [7.086367, 48.636967], [7.085961, 48.637235], [7.08425, 48.638278], [7.085063, 48.639218]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;57003_12236&quot;, &quot;properties&quot;: {&quot;comm_insee&quot;: &quot;57003&quot;, &quot;comm_nom&quot;: &quot;ABRESCHVILLER&quot;, &quot;dep&quot;: &quot;57&quot;, &quot;nature&quot;: &quot;Ademe&quot;, &quot;proprio_personne&quot;: &quot;personne morale&quot;, &quot;site_adresse&quot;: null, &quot;site_nom&quot;: &quot;57003_12236&quot;, &quot;site_statut&quot;: &quot;friche sans projet&quot;, &quot;site_type&quot;: &quot;inconnu&quot;, &quot;source_nom&quot;: &quot;Friche \u00e9tude Ademe 2021, int\u00e9ressante pour du PV au sol&quot;, &quot;unite_fonciere_refcad&quot;: &quot;[\u002757003000020082\u0027, \u002757003000020135\u0027, \u002757003000020141\u0027, \u002757003000020142\u0027, \u002757003000020143\u0027, \u002757003000020144\u0027, \u002757003000020145\u0027, \u002757003000130081\u0027, \u002757003000130082\u0027, \u002757003000130083\u0027, \u002757003000130119\u0027, \u002757003000130134\u0027, \u002757003000130135\u0027, \u002757003000130136\u0027, \u002757003000130137\u0027, \u002757003000130034\u0027, \u002757003000130040\u0027, \u002757003000130118\u0027, \u002757003000140046\u0027, \u002757003000140049\u0027, \u002757003000140050\u0027, \u002757003000140051\u0027, \u002757003000170271\u0027]&quot;, &quot;unite_fonciere_surface&quot;: 643924.5646376163, &quot;urba_zone_type&quot;: &quot;N&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[6.032167, 49.359513], [6.032175, 49.359606], [6.032103, 49.359596], [6.03191, 49.35957], [6.031753, 49.359547], [6.031603, 49.359527], [6.031473, 49.359509], [6.030671, 49.359399], [6.030467, 49.359387], [6.030466, 49.359375], [6.030471, 49.359175], [6.030477, 49.358913], [6.030491, 49.358913], [6.03049, 49.358909], [6.031051, 49.358868], [6.03133, 49.358852], [6.031754, 49.358829], [6.031754, 49.358831], [6.031753, 49.358881], [6.031877, 49.358918], [6.032416, 49.359076], [6.032331, 49.359393], [6.032167, 49.359513]]]], &quot;type&quot;: &quot;Mult
